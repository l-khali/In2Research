# %%
import numpy as np
import pandas as pd
from visits import Visit, Cohort, rolling_autocorrelation, age_histogram
import glob
import pymannkendall as mk
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cohort_1_details_flags = pd.read_csv("cohort_1_details_flags.csv", sep=',')
cohort_3_details_flags = pd.read_csv("cohort_3_details_flags.csv", sep=',')
cohort_4_details_flags = pd.read_csv("cohort_4_details_flags.csv", sep=',')

# %%
age_histogram(cohort_1_details_flags)

# %%
age_histogram(cohort_3_details_flags)

# %%
age_histogram(cohort_4_details_flags)
