# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
from matplotlib.ticker import PercentFormatter

# %%
rc('font', weight='bold')

PICU = [0.1875*12/27, 0.118873827*40/161,0.23*7/19,0.09456986*49/177,0.318181818*9/18,0.11953125*28/90]
PICU_patterns = ["\\", "\\", None, None, "\\","\\" ]
FLAMI = [0.1875*10/27, 0.118873827*84/161,0.23*9/19,0.09456986*92/177,0.318181818*7/18,0.11953125*57/90]
FLAMI_patterns = ["\\", "\\", "\\", "\\", "\\","\\" ]
NICU = [0.1875*5/27, 0.118873827*37/161,0.23*3/19,0.09456986*36/177,0.318181818*2/18,0.11953125*5/90]
NICU_patterns = ["\\", "\\", None, None, "\\","\\" ]

bars = np.add(PICU, FLAMI).tolist()

r = [0,1,3,4,6,7]
names = ['C1','C2','C1','C2', 'C1','C2']
barWidth = 1

plt.barh(r, PICU, color='#3d1a78', edgecolor='white', height=barWidth, label='PICU', hatch=PICU_patterns)
plt.barh(r, FLAMI, color='#078d70',left=PICU, edgecolor='white', height=barWidth, label='FLAMI', hatch=FLAMI_patterns)
plt.barh(r, NICU, color='#7bade2', left=bars, edgecolor='white', height=barWidth, label='NICU', hatch=NICU_patterns)
# plt.legend()
plt.title("Proportion of Instances Showing Significant Increase \n in Variance in Cohort 1 and Cohort 2")

plt.yticks(r, names, fontweight='bold') 
plt.ylabel("Heart          Respiration           Blood \n    Rate                Rate               Pressure")
plt.xlabel("Proportion of significant tests")
plt.xlim([0,0.35])
plt.show()

# %%
rc('font', weight='bold')

PICU = [0.142857143*4/20, 0.051094891*27/108,0.101010101*5/11,0.049420378*39/103,0.136363636*5/11,0.0515625*13/77]
PICU_patterns = [None,None, None, None, "\\","\\" ]
FLAMI = [0.142857143*1/2, 0.051094891*57/108,0.101010101*2/11,0.049420378*42/103,0.136363636*6/11,0.0515625*57/77]
FLAMI_patterns = ["\\", "\\", None,None, "\\","\\" ]
NICU = [0.142857143*6/20, 0.051094891*24/108,0.101010101*4/11,0.049420378*22/103,0.136363636*0,0.0515625*7/77]
NICU_patterns = ["\\", "\\", "\\","\\",None,None ]

bars = np.add(PICU, FLAMI).tolist()

r = [0,1,3,4,6,7]
names = ['C1','C2','C1','C2', 'C1','C2']
barWidth = 1

plt.barh(r, PICU, color='#3d1a78', edgecolor='white', height=barWidth, label='PICU', hatch=PICU_patterns)
plt.barh(r, FLAMI, color='#078d70',left=PICU, edgecolor='white', height=barWidth, label='FLAMI', hatch=FLAMI_patterns)
plt.barh(r, NICU, color='#7bade2', left=bars, edgecolor='white', height=barWidth, label='NICU', hatch=NICU_patterns)
plt.legend()
plt.title("Proportion of Instances Showing Significant Increase \n in Autocorrelation in Cohort 1 and Cohort 2")

plt.yticks(r, names, fontweight='bold') 
plt.ylabel("Heart          Respiration           Blood \n    Rate                Rate               Pressure")
plt.xlabel("Proportion of significant tests")
plt.xlim([0,0.35])
plt.show()

# %%
rc('font', weight='bold')

PICU = [0.13913*8/17, 0.118873827*40/161,0.156862745*9/18,0.09456986*49/177,0.161764706*2/11,0.11953125*28/90]
PICU_patterns = ["\\", "\\", None, None, None, None]
FLAMI = [0.13913*8/17, 0.118873827*84/161,0.156862745*7/18,0.09456986*92/177,0.161764706*8/11,0.11953125*57/90]
FLAMI_patterns = ["\\", "\\", "\\", "\\", "\\","\\" ]
NICU = [0.13913*1/17, 0.118873827*37/161,0.156862745*2/18,0.09456986*36/177,0.161764706*1/11,0.11953125*5/90]
NICU_patterns = [None, None, None, None, None, None]

bars = np.add(PICU, FLAMI).tolist()

r = [0,1,3,4,6,7]
names = ['C3','C2','C3','C2', 'C3','C2']
barWidth = 1

plt.barh(r, PICU, color='#3d1a78', edgecolor='white', height=barWidth, label='PICU', hatch=PICU_patterns)
plt.barh(r, FLAMI, color='#078d70',left=PICU, edgecolor='white', height=barWidth, label='FLAMI', hatch=FLAMI_patterns)
plt.barh(r, NICU, color='#7bade2', left=bars, edgecolor='white', height=barWidth, label='NICU', hatch=NICU_patterns)
# plt.legend()
plt.title("Proportion of Instances Showing Significant Increase \n in Variance in Cohort 3 and Cohort 2")

plt.yticks(r, names, fontweight='bold') 
plt.ylabel("Heart          Respiration           Blood \n    Rate                Rate               Pressure")
plt.xlabel("Proportion of significant tests")
plt.xlim([0,0.17])
plt.show()

# %%
rc('font', weight='bold')

PICU = [0.129310345*7/15, 0.051094891*27/108,0.066666667*5/9,0.049420378*39/103,0.089552239*5/7,0.0515625*13/77]
PICU_patterns = ["\\","\\", None, None, "\\","\\" ]
FLAMI = [0.129310345*6/15, 0.051094891*57/108,0.066666667*4/9,0.049420378*42/103,0.089552239*2/7,0.0515625*57/77]
FLAMI_patterns = ["\\", "\\", "\\","\\", None, None]
NICU = [0.129310345*2/15.129310345, 0.051094891*24/108,0.066666667*0,0.049420378*22/103,0.089552239*0,0.0515625*7/77]
NICU_patterns = [None,None ,None,None ,None,None ]

bars = np.add(PICU, FLAMI).tolist()

r = [0,1,3,4,6,7]
names = ['C3','C2','C3','C2', 'C3','C2']
barWidth = 1

plt.barh(r, PICU, color='#3d1a78', edgecolor='white', height=barWidth, label='PICU', hatch=PICU_patterns)
plt.barh(r, FLAMI, color='#078d70',left=PICU, edgecolor='white', height=barWidth, label='FLAMI', hatch=FLAMI_patterns)
plt.barh(r, NICU, color='#7bade2', left=bars, edgecolor='white', height=barWidth, label='NICU', hatch=NICU_patterns)
plt.legend()
plt.title("Proportion of Instances Showing Significant Increase \n in Autocorrelation in Cohort 3 and Cohort 2")

plt.yticks(r, names, fontweight='bold') 
plt.ylabel("Heart          Respiration           Blood \n    Rate                Rate               Pressure")
plt.xlabel("Proportion of significant tests")
plt.xlim([0,0.17])
plt.show()

# %%
rc('font', weight='bold')

PICU = [0, 0.118873827*40/161,0,0.09456986*49/177,0,0.11953125*28/90]
PICU_patterns = [None, None, None, None, None, None]
FLAMI = [0.181818182, 0.118873827*84/161,0,0.09456986*92/177,0.333333333,0.11953125*57/90]
FLAMI_patterns = [None, None, None, None, "\\","\\" ]
NICU = [0, 0.118873827*37/161,0,0.09456986*36/177,0,0.11953125*5/90]
NICU_patterns = [None, None, None, None, None, None]

bars = np.add(PICU, FLAMI).tolist()

r = [0,1,3,4,6,7]
names = ['C4','C2','C4','C2', 'C4','C2']
barWidth = 1

plt.barh(r, PICU, color='#3d1a78', edgecolor='white', height=barWidth, label='PICU', hatch=PICU_patterns)
plt.barh(r, FLAMI, color='#078d70',left=PICU, edgecolor='white', height=barWidth, label='FLAMI', hatch=FLAMI_patterns)
plt.barh(r, NICU, color='#7bade2', left=bars, edgecolor='white', height=barWidth, label='NICU', hatch=NICU_patterns)
# plt.legend()
plt.title("Proportion of Instances Showing Significant Increase \n in Variance in Cohort 4 and Cohort 2")

plt.yticks(r, names, fontweight='bold') 
plt.ylabel("Heart          Respiration           Blood \n    Rate                Rate               Pressure")
plt.xlabel("Proportion of significant tests")
plt.xlim([0,0.6])
plt.show()

# %%
rc('font', weight='bold')

PICU = [0.181818182*1/2, 0.051094891*27/108,0.454545455*3/5,0.049420378*39/103,0.555555556*2/5,0.0515625*13/77]
PICU_patterns = [None, None, "\\","\\" ,"\\","\\" ]
FLAMI = [0.181818182*1/2, 0.051094891*57/108,0.454545455*2/5,0.049420378*42/103,0.555555556*3/5,0.0515625*57/77]
FLAMI_patterns = [None, None, "\\","\\" ,"\\","\\" ]
NICU = [0, 0.051094891*24/108,0,0.049420378*22/103,0,0.0515625*7/77]
NICU_patterns = [None,None ,None,None ,None,None ]

bars = np.add(PICU, FLAMI).tolist()

r = [0,1,3,4,6,7]
names = ['C4','C2','C4','C2', 'C4','C2']
barWidth = 1

plt.barh(r, PICU, color='#3d1a78', edgecolor='white', height=barWidth, label='PICU', hatch=PICU_patterns)
plt.barh(r, FLAMI, color='#078d70',left=PICU, edgecolor='white', height=barWidth, label='FLAMI', hatch=FLAMI_patterns)
plt.barh(r, NICU, color='#7bade2', left=bars, edgecolor='white', height=barWidth, label='NICU', hatch=NICU_patterns)
plt.legend()
plt.title("Proportion of Instances Showing Significant Increase \n in Autocorrelation in Cohort 4 and Cohort 2")

plt.yticks(r, names, fontweight='bold') 
plt.ylabel("Heart          Respiration           Blood \n    Rate                Rate               Pressure")
plt.xlabel("Proportion of significant tests")
plt.xlim([0,0.6])
plt.show()

# %%
c1_var_hr_results = pd.read_csv("variance_results_c1.csv", sep=',')
c2_var_hr_results = pd.read_csv("variance_results_c2_entire.csv", sep=',')
c3_var_hr_results = pd.read_csv("variance_hr_results_c3_entire.csv", sep=',')
c4_var_hr_results = pd.read_csv("variance_hr_results_c4.csv", sep=',')

c1_var_rr_results = pd.read_csv("variance_rr_results_c1.csv", sep=',')
c2_var_rr_results = pd.read_csv("variance_rr_results_c2_pt1.csv", sep=',')
c3_var_rr_results = pd.read_csv("variance_rr_results_c3.csv", sep=',')
c4_var_rr_results = pd.read_csv("variance_rr_results_c4.csv", sep=',')

c1_var_abf_results = pd.read_csv("variance_abf_results_c1.csv", sep=',')
c2_var_abf_results = pd.read_csv("variance_abf_results_c2_pt1.csv", sep=',')
c3_var_abf_results = pd.read_csv("variance_abf_results_c3.csv", sep=',')
c4_var_abf_results = pd.read_csv("variance_abf_results_c4.csv", sep=',')

c1_ac_hr_results = pd.read_csv("autocorrelation_hr_results_c1.csv", sep=',')
c2_ac_hr_results = pd.read_csv("autocorrelation_hr_results_c2_partial.csv", sep=',')
c3_ac_hr_results = pd.read_csv("autocorrelation_hr_results_c3.csv", sep=',')
c4_ac_hr_results = pd.read_csv("autocorrelation_hr_results_c4.csv", sep=',')

c1_ac_rr_results = pd.read_csv("autocorrelation_rr_results_c1.csv", sep=',')
c2_ac_rr_results = pd.read_csv("autocorrelation_rr_results_c2_partial.csv", sep=',')
c3_ac_rr_results = pd.read_csv("autocorrelation_rr_results_c3.csv", sep=',')
c4_ac_rr_results = pd.read_csv("autocorrelation_rr_results_c4.csv", sep=',')

c1_ac_abf_results = pd.read_csv("autocorrelation_abf_results_c1.csv", sep=',')
c2_ac_abf_results = pd.read_csv("autocorrelation_abf_results_c2_partial.csv", sep=',')
c3_ac_abf_results = pd.read_csv("autocorrelation_abf_results_c3.csv", sep=',')
c4_ac_abf_results = pd.read_csv("autocorrelation_abf_results_c4.csv", sep=',')

# %%
rc('font', weight='bold')
plt.hist(c1_var_hr_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78')
plt.hist(c2_var_hr_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 2', color='#078d70')
plt.legend()
plt.xlabel(r"Kendall-Tau Correlation Coefficient, $\tau$")
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.title("Histogram of Correlation Coefficients of Variance of \n the Heart Rates of Instances in Cohort 1 and Cohort 2")
# Out:
# Text(0.5, 1.0, 'Histogram of Correlation Coefficients of Variance of \n the Heart Rates of Instances in Cohort 1 and Cohort 2')

# %%
rc('font', weight='bold')
plt.hist(c1_var_rr_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78')
plt.hist(c2_var_rr_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 2', color='#078d70')
plt.legend()
plt.xlabel(r"Kendall-Tau Correlation Coefficient, $\tau$")
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.title("Histogram of Correlation Coefficients of Variance of \n the Respiration Rates of Instances in Cohort 1 and Cohort 2")
# Out:
# Text(0.5, 1.0, 'Histogram of Correlation Coefficients of Variance of \n the Respiration Rates of Instances in Cohort 1 and Cohort 2')

# %%
rc('font', weight='bold')
plt.hist(c1_var_abf_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78')
plt.hist(c2_var_abf_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 2', color='#078d70')
plt.legend()
plt.xlabel(r"Kendall-Tau Correlation Coefficient, $\tau$")
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.title("Histogram of Correlation Coefficients of Variance of \n the Mean Blood Pressure of Instances in Cohort 1 and Cohort 2")
# Out:
# Text(0.5, 1.0, 'Histogram of Correlation Coefficients of Variance of \n the Mean Blood Pressure of Instances in Cohort 1 and Cohort 2')

# %%
rc('font', weight='bold')
plt.hist(c1_ac_hr_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78')
plt.hist(c2_ac_hr_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 2', color='#078d70')
plt.legend()
plt.xlabel(r"Kendall-Tau Correlation Coefficient, $\tau$")
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.title("Histogram of Correlation Coefficients of Autocorrelation of \n the Heart Rates of Instances in Cohort 1 and Cohort 2")
# Out:
# Text(0.5, 1.0, 'Histogram of Correlation Coefficients of Autocorrelation of \n the Heart Rates of Instances in Cohort 1 and Cohort 2')

# %%
rc('font', weight='bold')
plt.hist(c1_ac_rr_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78')
plt.hist(c2_ac_rr_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 2', color='#078d70')
plt.legend()
plt.xlabel(r"Kendall-Tau Correlation Coefficient, $\tau$")
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.title("Histogram of Correlation Coefficients of Autocorrelation of \n the Respiration Rates of Instances in Cohort 1 and Cohort 2")
# Out:
# Text(0.5, 1.0, 'Histogram of Correlation Coefficients of Autocorrelation of \n the Respiration Rates of Instances in Cohort 1 and Cohort 2')

# %%
rc('font', weight='bold')
plt.hist(c1_ac_abf_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78')
plt.hist(c2_ac_abf_results["tau"], alpha=0.5, density=True, edgecolor='white', bins=50, label='Cohort 2', color='#078d70')
plt.legend()
plt.xlabel(r"Kendall-Tau Correlation Coefficient, $\tau$")
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.title("Histogram of Correlation Coefficients of Autocorrelation of \n the Mean Blood Pressure of Instances in Cohort 1 and Cohort 2")
# Out:
# Text(0.5, 1.0, 'Histogram of Correlation Coefficients of Autocorrelation of \n the Mean Blood Pressure of Instances in Cohort 1 and Cohort 2')

# %%
fig, axs = plt.subplots(2, 3, figsize=(33, 22), sharex=True, sharey=True)

plt.rcParams['font.size'] = '30'
rc('font', weight='bold')

axs[0,0].hist(c1_var_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78', weights=np.ones_like(c1_var_hr_results["tau"]) / len(c1_var_hr_results["tau"]))
axs[0,0].hist(c2_var_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_var_hr_results["tau"]) / len(c2_var_hr_results["tau"]))
axs[0,0].legend()
axs[0,0].set(title="Heart Rate \n (beats per minute/ BPM) \n")

axs[1,0].hist(c1_ac_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78', weights=np.ones_like(c1_ac_hr_results["tau"]) / len(c1_ac_hr_results["tau"]))
axs[1,0].hist(c2_ac_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_ac_hr_results["tau"]) / len(c2_ac_hr_results["tau"]))
# axs[1,0].legend()
# axs[1,0].set(xlabel=r"Kendall-Tau Correlation Coefficient, $\tau$")

axs[0,1].hist(c1_var_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78', weights=np.ones_like(c1_var_rr_results["tau"]) / len(c1_var_rr_results["tau"]))
axs[0,1].hist(c2_var_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_var_rr_results["tau"]) / len(c2_var_rr_results["tau"]))
# axs[0,1].legend()
axs[0,1].set(title="Respiration Rate \n (breaths per minute/ BrPM) \n")

axs[1,1].hist(c1_ac_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78', weights=np.ones_like(c1_ac_rr_results["tau"]) / len(c1_ac_rr_results["tau"]))
axs[1,1].hist(c2_ac_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_ac_rr_results["tau"]) / len(c2_ac_rr_results["tau"]))
# axs[1,0].legend()
# axs[1,1].set(xlabel=r"Kendall-Tau Correlation Coefficient, $\tau$")

axs[0,2].hist(c1_var_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78', weights=np.ones_like(c1_var_abf_results["tau"]) / len(c1_var_abf_results["tau"]))
axs[0,2].hist(c2_var_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_var_abf_results["tau"]) / len(c2_var_abf_results["tau"]))
# axs[0,1].legend()
axs[0,2].set(title="Mean Blood Pressure \n (millimeters of mercury/ mmHg) \n")

axs[1,2].hist(c1_ac_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 1', color='#3d1a78', weights=np.ones_like(c1_ac_abf_results["tau"]) / len(c1_ac_abf_results["tau"]))
axs[1,2].hist(c2_ac_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_ac_abf_results["tau"]) / len(c2_ac_abf_results["tau"]))
# axs[1,0].legend()
# axs[1,2].set(xlabel=r"Kendall-Tau Correlation Coefficient, $\tau$")

fig.supxlabel(r"Kendall-Tau Correlation Coefficient, $\tau$")
fig.supylabel(r"Relative Frequency")
axs[0,0].set(ylabel=r"Variance, $\sigma^2$")
axs[1,0].set(ylabel=r"Autocorrelation, $r_1$")
# Out:
# [Text(0, 0.5, 'Autocorrelation, $r_1$')]

# %%
fig, axs = plt.subplots(2, 3, figsize=(33, 22), sharex=True, sharey=True)

plt.rcParams['font.size'] = '30'
rc('font', weight='bold')

axs[0,0].hist(c3_var_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 3', color='#3d1a78', weights=np.ones_like(c3_var_hr_results["tau"]) / len(c3_var_hr_results["tau"]))
axs[0,0].hist(c2_var_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_var_hr_results["tau"]) / len(c2_var_hr_results["tau"]))
axs[0,0].legend()
axs[0,0].set(title="Heart Rate \n (beats per minute/ BPM) \n")

axs[1,0].hist(c3_ac_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 3', color='#3d1a78', weights=np.ones_like(c3_ac_hr_results["tau"]) / len(c3_ac_hr_results["tau"]))
axs[1,0].hist(c2_ac_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_ac_hr_results["tau"]) / len(c2_ac_hr_results["tau"]))
# axs[1,0].legend()
# axs[1,0].set(xlabel=r"Kendall-Tau Correlation Coefficient, $\tau$")

axs[0,1].hist(c3_var_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 3', color='#3d1a78', weights=np.ones_like(c3_var_rr_results["tau"]) / len(c3_var_rr_results["tau"]))
axs[0,1].hist(c2_var_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_var_rr_results["tau"]) / len(c2_var_rr_results["tau"]))
# axs[0,1].legend()
axs[0,1].set(title="Respiration Rate \n (breaths per minute/ BrPM) \n")

axs[1,1].hist(c3_ac_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 3', color='#3d1a78', weights=np.ones_like(c3_ac_rr_results["tau"]) / len(c3_ac_rr_results["tau"]))
axs[1,1].hist(c2_ac_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_ac_rr_results["tau"]) / len(c2_ac_rr_results["tau"]))
# axs[1,0].legend()
# axs[1,1].set(xlabel=r"Kendall-Tau Correlation Coefficient, $\tau$")

axs[0,2].hist(c3_var_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 3', color='#3d1a78', weights=np.ones_like(c3_var_abf_results["tau"]) / len(c3_var_abf_results["tau"]))
axs[0,2].hist(c2_var_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_var_abf_results["tau"]) / len(c2_var_abf_results["tau"]))
# axs[0,1].legend()
axs[0,2].set(title="Mean Blood Pressure \n (millimeters of mercury/ mmHg) \n")

axs[1,2].hist(c3_ac_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 3', color='#3d1a78', weights=np.ones_like(c3_ac_abf_results["tau"]) / len(c3_ac_abf_results["tau"]))
axs[1,2].hist(c2_ac_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_ac_abf_results["tau"]) / len(c2_ac_abf_results["tau"]))
# axs[1,0].legend()
# axs[1,2].set(xlabel=r"Kendall-Tau Correlation Coefficient, $\tau$")

fig.supxlabel(r"Kendall-Tau Correlation Coefficient, $\tau$")
fig.supylabel(r"Relative Frequency")
axs[0,0].set(ylabel=r"Variance, $\sigma^2$")
axs[1,0].set(ylabel=r"Autocorrelation, $r_1$")
# Out:
# [Text(0, 0.5, 'Autocorrelation, $r_1$')]

# %%
fig, axs = plt.subplots(2, 3, figsize=(33, 22), sharex=True, sharey=True)

plt.rcParams['font.size'] = '30'
rc('font', weight='bold')

axs[0,0].hist(c4_var_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 4', color='#3d1a78', weights=np.ones_like(c4_var_hr_results["tau"]) / len(c4_var_hr_results["tau"]))
axs[0,0].hist(c2_var_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_var_hr_results["tau"]) / len(c2_var_hr_results["tau"]))
axs[0,0].legend()
axs[0,0].set(title="Heart Rate \n (beats per minute/ BPM) \n")

axs[1,0].hist(c4_ac_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 4', color='#3d1a78', weights=np.ones_like(c4_ac_hr_results["tau"]) / len(c4_ac_hr_results["tau"]))
axs[1,0].hist(c2_ac_hr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_ac_hr_results["tau"]) / len(c2_ac_hr_results["tau"]))
# axs[1,0].legend()
# axs[1,0].set(xlabel=r"Kendall-Tau Correlation Coefficient, $\tau$")

axs[0,1].hist(c4_var_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 4', color='#3d1a78', weights=np.ones_like(c4_var_rr_results["tau"]) / len(c4_var_rr_results["tau"]))
axs[0,1].hist(c2_var_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_var_rr_results["tau"]) / len(c2_var_rr_results["tau"]))
# axs[0,1].legend()
axs[0,1].set(title="Respiration Rate \n (breaths per minute/ BrPM) \n")

axs[1,1].hist(c4_ac_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 4', color='#3d1a78', weights=np.ones_like(c4_ac_rr_results["tau"]) / len(c4_ac_rr_results["tau"]))
axs[1,1].hist(c2_ac_rr_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_ac_rr_results["tau"]) / len(c2_ac_rr_results["tau"]))
# axs[1,0].legend()
# axs[1,1].set(xlabel=r"Kendall-Tau Correlation Coefficient, $\tau$")

axs[0,2].hist(c4_var_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 4', color='#3d1a78', weights=np.ones_like(c4_var_abf_results["tau"]) / len(c4_var_abf_results["tau"]))
axs[0,2].hist(c2_var_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_var_abf_results["tau"]) / len(c2_var_abf_results["tau"]))
# axs[0,1].legend()
axs[0,2].set(title="Mean Blood Pressure \n (millimeters of mercury/ mmHg) \n")

axs[1,2].hist(c4_ac_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 4', color='#3d1a78', weights=np.ones_like(c4_ac_abf_results["tau"]) / len(c4_ac_abf_results["tau"]))
axs[1,2].hist(c2_ac_abf_results["tau"], alpha=0.5, edgecolor='white', bins=50, label='Cohort 2', color='#078d70', weights=np.ones_like(c2_ac_abf_results["tau"]) / len(c2_ac_abf_results["tau"]))
# axs[1,0].legend()
# axs[1,2].set(xlabel=r"Kendall-Tau Correlation Coefficient, $\tau$")

fig.supxlabel(r"Kendall-Tau Correlation Coefficient, $\tau$")
fig.supylabel(r"Relative Frequency")
axs[0,0].set(ylabel=r"Variance, $\sigma^2$")
axs[1,0].set(ylabel=r"Autocorrelation, $r_1$")
# Out:
# [Text(0, 0.5, 'Autocorrelation, $r_1$')]
